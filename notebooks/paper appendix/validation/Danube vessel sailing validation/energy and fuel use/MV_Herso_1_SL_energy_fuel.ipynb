# %% [markdown]
# ## Herso 1 sailing with the SL lighter
# ### Estimate Fuel use with vessel speed, h_0, current speed as input
#
# - upstream 'Herso 1 + SL' longer formation
# - downstream 'Herso 1 + SL' wider formation

# %% [markdown]
# ### Imports
# Import the required libraries

# %%
# package(s) related to time, space and id
import logging
import datetime, time
import platform
import itertools
# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# spatial libraries 
import pyproj
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np
import matplotlib.pyplot as plt

# OpenTNSim
import opentnsim

# Used for mathematical functions
import math             
import tqdm
# Used for making the graph to visualize our problem
import networkx as nx   

import plotly.express as px
from plotly.subplots import make_subplots

#logging.basicConfig(level=logging.DEBUG) #turn on all the debug messages
logging.basicConfig(level=logging.INFO)# turn off all the debug messages

# %% [markdown]
# ### create graph with navigation info

# %%
# specify a number of coordinate along your route (coords are: lon, lat)
coords = [
    [0,0],
    [0.4366,0],
    [0.8528,0], 
    [1.1443,0],
    [1.31495,0],
    [1.56274,0],
    [1.736384,0],
    [2.0710,0], 
    [2.20665,0],
    [3.05674,0],
    [3.32804,0],
    [4.1148,0],
    [4.54888,0], 
    [4.73879,0],
    [5.07844,0],
    [6.62475,0], 
] 

# for each edge (between above coordinates) specify the depth (m)
depths = [7.5, 4.18, 4.18, 7.83, 7.5, 6.5, 10.6, 6.45, 8.04, 5.65, 8.87, 4.93, 7.7, 9.8, 5.45]
current_speeds = [-2.24* 0.2777,-3.4* 0.2777,-4.93* 0.2777,-2.59* 0.2777,-3.26* 0.2777,
                     -3.85* 0.2777,-1.87* 0.2777,-1.08* 0.2777,-2.83* 0.2777,-4.99* 0.2777,
                     -2.89* 0.2777,-6.4* 0.2777,-3.42* 0.2777,-1.64* 0.2777,-4.1* 0.2777]  # [m/s]

V_g_profile_up = [3.511429, 2.932533,2.507533, 3.417898,3.228096, 2.962490,3.646894,3.728326,3.366366, 2.719507,
3.351586,2.237576,3.186054,3.059887,2.915116] # [m/s] for upstream

V_g_profile_down = [4.44, 4.44, 4.44, 4.44,4.44, 4.44, 4.44, 4.44, 4.44, 4.44,4.44, 4.44, 4.44, 3.33, 4.44] # [m/s] for downstream

# power_applied = [620, 620, 620, 620, 620, 620, 620, 620, 620,620, 620, 620,620, 250, 620] ## [kW] for upstream
# check of nr of coords and nr of depths align
assert len(coords) == len(depths) + 1, 'nr of depths does not correspond to nr of coords'

# %%
# create a graph based on coords and depths
FG = nx.DiGraph()
nodes = []
path = []

# add nodes
Node = type('Site', (opentnsim.core.Identifiable, opentnsim.core.Locatable), {})

for index, coord in enumerate(coords):
    data_node = {"name": "Node " + str(index), "geometry": shapely.geometry.Point(coord[0], coord[1])}
    nodes.append(Node(**data_node))
    
positions = {}
for node in nodes:
    positions[node.name] = (node.geometry.x, node.geometry.y)
    FG.add_node(node.name, geometry = node.geometry)

# add edges
path = [[nodes[i], nodes[i+1]] for i in range(len(nodes)-1)]

for index, edge in enumerate(path):
    # For the energy consumption calculation we add info to the graph. We need depth info for resistance.
    # NB: the CalculateEnergy routine expects the graph to have "Info" that contains "GeneralDepth" 
    #     this may not be very generic!
    FG.add_edge(edge[0].name, edge[1].name, weight = 1, Info = {
        "GeneralDepth": depths[index],
        "CurrentSpeed": current_speeds[index],
        "VesselSpeedToGroundProfile_upstream": V_g_profile_up[index],
        "VesselSpeedToGroundProfile_downstream": V_g_profile_down[index]
    })

# toggle to undirected and back to directed to make sure all edges are two way traffic
FG = FG.to_undirected() 
FG = FG.to_directed()

# %%
# show graph
nx.draw(FG, positions, node_size=80)

plt.show()

# %%
# This cell just shows that now a depth of 10 m is added to the edges. 
# You can use this to vary depths, e.g. make the middle edge shallower. Note that edges are bi-directional 
for edge in FG.edges:
    print('General depth for edge {} is {} m'.format(edge, FG.get_edge_data(edge[0], edge[1])["Info"]["GeneralDepth"]))
    print('Current speed for edge {} is {} m/s'.format(edge, FG.get_edge_data(edge[0], edge[1])["Info"]["CurrentSpeed"]))
    print('Vessel Speed To Ground for edge {} is {} m/s while sailing upstream'.format(edge, FG.get_edge_data(edge[0], edge[1])["Info"]["VesselSpeedToGroundProfile_upstream"]))
    print('Vessel Speed To Ground for edge {} is {} m/s while sailing downstream'.format(edge, FG.get_edge_data(edge[0], edge[1])["Info"]["VesselSpeedToGroundProfile_downstream"]))
# Out:
# General depth for edge ('Node 0', 'Node 1') is 7.5 m
# Current speed for edge ('Node 0', 'Node 1') is -0.622048 m/s
# Vessel Speed To Ground for edge ('Node 0', 'Node 1') is 3.511429 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 0', 'Node 1') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 1', 'Node 0') is 7.5 m
# Current speed for edge ('Node 1', 'Node 0') is -0.622048 m/s
# Vessel Speed To Ground for edge ('Node 1', 'Node 0') is 3.511429 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 1', 'Node 0') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 1', 'Node 2') is 4.18 m
# Current speed for edge ('Node 1', 'Node 2') is -0.94418 m/s
# Vessel Speed To Ground for edge ('Node 1', 'Node 2') is 2.932533 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 1', 'Node 2') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 2', 'Node 1') is 4.18 m
# Current speed for edge ('Node 2', 'Node 1') is -0.94418 m/s
# Vessel Speed To Ground for edge ('Node 2', 'Node 1') is 2.932533 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 2', 'Node 1') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 2', 'Node 3') is 4.18 m
# Current speed for edge ('Node 2', 'Node 3') is -1.3690609999999999 m/s
# Vessel Speed To Ground for edge ('Node 2', 'Node 3') is 2.507533 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 2', 'Node 3') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 3', 'Node 2') is 4.18 m
# Current speed for edge ('Node 3', 'Node 2') is -1.3690609999999999 m/s
# Vessel Speed To Ground for edge ('Node 3', 'Node 2') is 2.507533 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 3', 'Node 2') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 3', 'Node 4') is 7.83 m
# Current speed for edge ('Node 3', 'Node 4') is -0.719243 m/s
# Vessel Speed To Ground for edge ('Node 3', 'Node 4') is 3.417898 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 3', 'Node 4') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 4', 'Node 3') is 7.83 m
# Current speed for edge ('Node 4', 'Node 3') is -0.719243 m/s
# Vessel Speed To Ground for edge ('Node 4', 'Node 3') is 3.417898 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 4', 'Node 3') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 4', 'Node 5') is 7.5 m
# Current speed for edge ('Node 4', 'Node 5') is -0.9053019999999999 m/s
# Vessel Speed To Ground for edge ('Node 4', 'Node 5') is 3.228096 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 4', 'Node 5') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 5', 'Node 4') is 7.5 m
# Current speed for edge ('Node 5', 'Node 4') is -0.9053019999999999 m/s
# Vessel Speed To Ground for edge ('Node 5', 'Node 4') is 3.228096 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 5', 'Node 4') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 5', 'Node 6') is 6.5 m
# Current speed for edge ('Node 5', 'Node 6') is -1.069145 m/s
# Vessel Speed To Ground for edge ('Node 5', 'Node 6') is 2.96249 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 5', 'Node 6') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 6', 'Node 5') is 6.5 m
# Current speed for edge ('Node 6', 'Node 5') is -1.069145 m/s
# Vessel Speed To Ground for edge ('Node 6', 'Node 5') is 2.96249 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 6', 'Node 5') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 6', 'Node 7') is 10.6 m
# Current speed for edge ('Node 6', 'Node 7') is -0.5192990000000001 m/s
# Vessel Speed To Ground for edge ('Node 6', 'Node 7') is 3.646894 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 6', 'Node 7') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 7', 'Node 6') is 10.6 m
# Current speed for edge ('Node 7', 'Node 6') is -0.5192990000000001 m/s
# Vessel Speed To Ground for edge ('Node 7', 'Node 6') is 3.646894 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 7', 'Node 6') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 7', 'Node 8') is 6.45 m
# Current speed for edge ('Node 7', 'Node 8') is -0.299916 m/s
# Vessel Speed To Ground for edge ('Node 7', 'Node 8') is 3.728326 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 7', 'Node 8') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 8', 'Node 7') is 6.45 m
# Current speed for edge ('Node 8', 'Node 7') is -0.299916 m/s
# Vessel Speed To Ground for edge ('Node 8', 'Node 7') is 3.728326 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 8', 'Node 7') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 8', 'Node 9') is 8.04 m
# Current speed for edge ('Node 8', 'Node 9') is -0.785891 m/s
# Vessel Speed To Ground for edge ('Node 8', 'Node 9') is 3.366366 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 8', 'Node 9') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 9', 'Node 8') is 8.04 m
# Current speed for edge ('Node 9', 'Node 8') is -0.785891 m/s
# Vessel Speed To Ground for edge ('Node 9', 'Node 8') is 3.366366 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 9', 'Node 8') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 9', 'Node 10') is 5.65 m
# Current speed for edge ('Node 9', 'Node 10') is -1.385723 m/s
# Vessel Speed To Ground for edge ('Node 9', 'Node 10') is 2.719507 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 9', 'Node 10') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 10', 'Node 9') is 5.65 m
# Current speed for edge ('Node 10', 'Node 9') is -1.385723 m/s
# Vessel Speed To Ground for edge ('Node 10', 'Node 9') is 2.719507 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 10', 'Node 9') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 10', 'Node 11') is 8.87 m
# Current speed for edge ('Node 10', 'Node 11') is -0.8025530000000001 m/s
# Vessel Speed To Ground for edge ('Node 10', 'Node 11') is 3.351586 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 10', 'Node 11') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 11', 'Node 10') is 8.87 m
# Current speed for edge ('Node 11', 'Node 10') is -0.8025530000000001 m/s
# Vessel Speed To Ground for edge ('Node 11', 'Node 10') is 3.351586 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 11', 'Node 10') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 11', 'Node 12') is 4.93 m
# Current speed for edge ('Node 11', 'Node 12') is -1.7772800000000002 m/s
# Vessel Speed To Ground for edge ('Node 11', 'Node 12') is 2.237576 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 11', 'Node 12') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 12', 'Node 11') is 4.93 m
# Current speed for edge ('Node 12', 'Node 11') is -1.7772800000000002 m/s
# Vessel Speed To Ground for edge ('Node 12', 'Node 11') is 2.237576 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 12', 'Node 11') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 12', 'Node 13') is 7.7 m
# Current speed for edge ('Node 12', 'Node 13') is -0.949734 m/s
# Vessel Speed To Ground for edge ('Node 12', 'Node 13') is 3.186054 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 12', 'Node 13') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 13', 'Node 12') is 7.7 m
# Current speed for edge ('Node 13', 'Node 12') is -0.949734 m/s
# Vessel Speed To Ground for edge ('Node 13', 'Node 12') is 3.186054 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 13', 'Node 12') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 13', 'Node 14') is 9.8 m
# Current speed for edge ('Node 13', 'Node 14') is -0.455428 m/s
# Vessel Speed To Ground for edge ('Node 13', 'Node 14') is 3.059887 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 13', 'Node 14') is 3.33 m/s while sailing downstream
# General depth for edge ('Node 14', 'Node 13') is 9.8 m
# Current speed for edge ('Node 14', 'Node 13') is -0.455428 m/s
# Vessel Speed To Ground for edge ('Node 14', 'Node 13') is 3.059887 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 14', 'Node 13') is 3.33 m/s while sailing downstream
# General depth for edge ('Node 14', 'Node 15') is 5.45 m
# Current speed for edge ('Node 14', 'Node 15') is -1.1385699999999999 m/s
# Vessel Speed To Ground for edge ('Node 14', 'Node 15') is 2.915116 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 14', 'Node 15') is 4.44 m/s while sailing downstream
# General depth for edge ('Node 15', 'Node 14') is 5.45 m
# Current speed for edge ('Node 15', 'Node 14') is -1.1385699999999999 m/s
# Vessel Speed To Ground for edge ('Node 15', 'Node 14') is 2.915116 m/s while sailing upstream
# Vessel Speed To Ground for edge ('Node 15', 'Node 14') is 4.44 m/s while sailing downstream

# %% [markdown]
# ### Create vessel - add VesselProperties and ConsumesEnergy mixins

# %%
# Make your preferred class out of available mix-ins.
TransportResource = type(
    "Vessel",
    (
        opentnsim.core.Identifiable,
        opentnsim.core.Movable,
        opentnsim.core.VesselProperties,  # needed to add vessel properties
        opentnsim.energy.ConsumesEnergy,
        opentnsim.core.ExtraMetadata,
    ),
    {},
)  # needed to calculate resistances

# %%
# Create a dict with all important settings

data_vessel_up = {
    "env": None,
    "name": 'Vessel M6',
    "route": None,
    "geometry": None,
    "v": None,  # m/s
    "V_g_ave":3.53,
    "use_V_g_profile":True,
    "type": None,
    "B": 10.5,
    "L": 155.75,
    "H_e": None, 
    "H_f": None, 
    "T": 2,
    "safety_margin": 0.3, # for tanker vessel with rocky bed the safety margin is recommended as 0.3 m
    "h_squat": False, # if consider the ship squatting while moving, set to True, otherwise set to False. Note that here we have disabled h_squat calculation since we regard the water depth h_0 is already reduced by squat effect. This applies to figures 3, 5, 7, 8 and 9.
    "payload":None,
    "vessel_type":"Dry_DH", #vessel types: "Container","Dry_SH","Dry_DH","Barge","Tanker". ("Dry_SH" means dry bulk single hull, "Dry_DH" means dry bulk double hull)    
    "P_installed": 780.0,   
    "P_tot_given": None, # kW
    "P_tot_given_profile":False,
    "bulbous_bow": False, # if a vessel has no bulbous_bow, set to False; otherwise set to True.
    "sailing_on_power": False,
    "sailing_upstream":True,
    "wind_influence": False,
    "P_hotel_perc": 0,
    "P_hotel": None, # None: calculate P_hotel from percentage
    "x": 1,# number of propellers
    "L_w": 2.0 ,
    "C_B":0.85, 
    "C_year": 2000, # although the construction year of Herso 1 is 1961, checking with the SFC used in the paper,it is similar as year of 2000
}

# %%
# Create a dict with all important settings

data_vessel_down = {
    "env": None,
    "name": 'Vessel M6',
    "route": None,
    "geometry": None,
    "v": None,  # m/s
    "V_g_ave":3.53,
    "use_V_g_profile":True,
    "type": None,
    "B": 20,
    "L": 85,
    "H_e": None, 
    "H_f": None, 
    "T":1.5,
    "safety_margin": 0.3, # for tanker vessel with rocky bed the safety margin is recommended as 0.3 m
    "h_squat": False, # if consider the ship squatting while moving, set to True, otherwise set to False. Note that here we have disabled h_squat calculation since we regard the water depth h_0 is already reduced by squat effect. This applies to figures 3, 5, 7, 8 and 9.
    "payload":None,
    "vessel_type":"Dry_DH", #vessel types: "Container","Dry_SH","Dry_DH","Barge","Tanker". ("Dry_SH" means dry bulk single hull, "Dry_DH" means dry bulk double hull)    
    "P_installed": 780.0,   
    "P_tot_given": None, # kW
    "P_tot_given_profile":False,
    "bulbous_bow": False, # if a vessel has no bulbous_bow, set to False; otherwise set to True.
    "sailing_on_power": False,
    "sailing_upstream":False,
    "wind_influence": False,
    "P_hotel_perc": 0,
    "P_hotel": None, # None: calculate P_hotel from percentage
    "x": 1,# number of propellers
    "L_w": 2.0 ,
    "C_B":0.902, 
    "C_year": 2000,
}

# %% [markdown]
# ### define sailing paths

# %%
path_upstream = nx.dijkstra_path(FG, nodes[0].name, nodes[15].name)
path_downstream = nx.dijkstra_path(FG, nodes[15].name, nodes[0].name)

# %% [markdown]
# ### define simulation "Herso 1 sailing upstream and downstream"

# %%
def run_simulation(path,**data_vessel):
    
    # Start simpy environment
    simulation_start = datetime.datetime.now()
    env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
    env.epoch = time.mktime(simulation_start.timetuple())

    # Add graph to environment
    env.FG = FG

    # Add environment and path to the vessel
    # create a fresh instance of vessel
    vessel = TransportResource(**data_vessel)
    vessel.env = env                                        #the created environment
    vessel.name = 'Vessel No.1'                     
    vessel.route = path                                     #the route (the sequence of nodes, as stored as the second column in the path)
    vessel.geometry = env.FG.nodes[path[0]]['geometry']     #a shapely.geometry.Point(lon,lat) (here taken as the starting node of the vessel)
    # vessel.V_g_ave = V_g_ave
    # vessel.sailing_upstream = sailing_upstream
    # vessel.P_tot_given = P_tot_given
    # Start the simulation
    env.process(vessel.move())
    env.run()
    
    return vessel

# %% [markdown]
# ### run simulation to get energy consumption

# %% [markdown]
# ### upstream energy consumption

# %%
vessel_upstream = run_simulation(path = path_upstream, **data_vessel_up)
# create an EnergyCalculation object and perform energy consumption calculation
energycalculation_upstream = opentnsim.energy.EnergyCalculation(FG, vessel_upstream)
energycalculation_upstream.calculate_energy_consumption()

# create dataframe from energy calculation computation
df_upstream = pd.DataFrame.from_dict(energycalculation_upstream.energy_use)
selected = ['edge_start','edge_stop','P_tot','P_installed','total_energy','total_diesel_consumption_C_year_ICE_mass','total_diesel_consumption_ICE_vol',
            'total_emission_CO2','total_emission_PM10','total_emission_NOX',
            'total_LH2_consumption_PEMFC_mass','total_LH2_consumption_SOFC_mass','total_LH2_consumption_PEMFC_vol','total_LH2_consumption_SOFC_vol',
           'total_eLNG_consumption_PEMFC_mass','total_eLNG_consumption_SOFC_mass','total_eLNG_consumption_PEMFC_vol','total_eLNG_consumption_SOFC_vol',
            'total_eLNG_consumption_ICE_mass','total_eLNG_consumption_ICE_vol',
            'total_eMethanol_consumption_PEMFC_mass','total_eMethanol_consumption_SOFC_mass','total_eMethanol_consumption_PEMFC_vol','total_eMethanol_consumption_SOFC_vol',
            'total_eMethanol_consumption_ICE_mass','total_eMethanol_consumption_ICE_vol','total_eNH3_consumption_PEMFC_mass','total_eNH3_consumption_SOFC_mass',
            'total_eNH3_consumption_PEMFC_vol','total_eNH3_consumption_SOFC_vol','total_eNH3_consumption_ICE_mass','total_eNH3_consumption_ICE_vol',
            'total_Li_NMC_Battery_mass','total_Li_NMC_Battery_vol','total_Battery2000kWh_consumption_num']
df_upstream = df_upstream[selected]
df_upstream
# Out:
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 205.0 SFC final
# 214.92948475596245 SFC final
# 205.0 SFC final
# C:\ANACONDA2021\envs\sim\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#             edge_start           edge_stop       P_tot  P_installed  \
# 0          POINT (0 0)    POINT (0.4366 0)  632.557163        780.0
# 1     POINT (0.4366 0)    POINT (0.8528 0)  632.450212        780.0
# 2     POINT (0.8528 0)    POINT (1.1443 0)  632.359006        780.0
# 3     POINT (1.1443 0)   POINT (1.31495 0)  632.543672        780.0
# 4    POINT (1.31495 0)   POINT (1.56274 0)  632.513708        780.0
# 5    POINT (1.56274 0)  POINT (1.736384 0)  632.477173        780.0
# 6   POINT (1.736384 0)     POINT (2.071 0)  632.584043        780.0
# 7      POINT (2.071 0)   POINT (2.20665 0)  632.602527        780.0
# 8    POINT (2.20665 0)   POINT (3.05674 0)  632.535114        780.0
# 9    POINT (3.05674 0)   POINT (3.32804 0)  632.415991        780.0
# 10   POINT (3.32804 0)    POINT (4.1148 0)  632.536237        780.0
# 11    POINT (4.1148 0)   POINT (4.54888 0)  632.317350        780.0
# 12   POINT (4.54888 0)   POINT (4.73879 0)  632.507771        780.0
# 13   POINT (4.73879 0)   POINT (5.07844 0)  357.097607        780.0
# 14   POINT (5.07844 0)   POINT (6.62475 0)  632.447161        780.0
#
#     total_energy  total_diesel_consumption_C_year_ICE_mass  \
# 0    2432.026643                              4.985655e+05
# 1    2775.583012                              5.689945e+05
# 2    2273.130244                              4.659917e+05
# 3     976.576840                              2.001983e+05
# 4    1501.329391                              3.077725e+05
# 5    1146.347939                              2.350013e+05
# 6    1794.777044                              3.679293e+05
# 7     711.714069                              1.459014e+05
# 8    4939.203561                              1.012537e+06
# 9    1950.882738                              3.999310e+05
# 10   4591.409461                              9.412389e+05
# 11   3793.113082                              7.775882e+05
# 12   1165.814030                              2.389919e+05
# 13   1225.693494                              2.634377e+05
# 14  10373.699916                              2.126608e+06
#
#     total_diesel_consumption_ICE_vol  total_emission_CO2  total_emission_PM10  \
# 0                           0.643611        1.580817e+06           713.414968
# 1                           0.734530        1.804129e+06           814.217231
# 2                           0.601561        1.477535e+06           666.838668
# 3                           0.258441        6.347749e+05           286.471779
# 4                           0.397312        9.758641e+05           440.407619
# 5                           0.303369        7.451262e+05           336.278772
# 6                           0.474970        1.166605e+06           526.479340
# 7                           0.188348        4.626141e+05           208.772972
# 8                           1.307110        3.210482e+06          1448.883027
# 9                           0.516281        1.268074e+06           572.296555
# 10                          1.215070        2.984416e+06          1346.859508
# 11                          1.003809        2.465524e+06          1112.748427
# 12                          0.308521        7.577791e+05           341.986365
# 13                          0.340079        8.352902e+05           371.385129
# 14                          2.745295        6.742905e+06          3043.127136
#
#     total_emission_NOX  total_LH2_consumption_PEMFC_mass  \
# 0         22175.218930                     193133.914249
# 1         25307.765902                     220416.668945
# 2         20726.401566                     180515.514884
# 3          8904.427623                      77552.648588
# 4         13689.121386                     119224.689696
# 5         10452.400512                      91034.637834
# 6         16364.777091                     142528.173698
# 7          6489.408883                      56519.168663
# 8         45035.658071                     392235.718240
# 9         17788.148801                     154924.955472
# 10        41864.471466                     364616.433677
# 11        34585.605079                     301221.526005
# 12        10629.892326                      92580.493541
# 13        11618.720260                      87520.322862
# 14        94587.395834                     823803.997331
#
#     total_LH2_consumption_SOFC_mass  total_LH2_consumption_PEMFC_vol  \
# 0                     176904.173556                         2.516181
# 1                     201894.259790                         2.871626
# 2                     165346.143885                         2.351787
# 3                      71035.619295                         1.010369
# 4                     109205.808209                         1.553279
# 5                      83384.668268                         1.186015
# 6                     130551.016245                         1.856881
# 7                      51769.658691                         0.736341
# 8                     359274.733514                         5.110113
# 9                     141906.051651                         2.018389
# 10                    333976.397234                         4.750285
# 11                    275908.792727                         3.924365
# 12                     84800.620134                         1.206154
# 13                     85066.482034                         1.140230
# 14                    754576.770665                        10.732658
#
#     total_LH2_consumption_SOFC_vol  total_eLNG_consumption_PEMFC_mass  \
# 0                         2.304737                       4.835609e+05
# 1                         2.630313                       5.518703e+05
# 2                         2.154158                       4.519674e+05
# 3                         0.925464                       1.941732e+05
# 4                         1.422752                       2.985099e+05
# 5                         1.086350                       2.279288e+05
# 6                         1.700841                       3.568563e+05
# 7                         0.674464                       1.415104e+05
# 8                         4.680692                       9.820639e+05
# 9                         1.848776                       3.878948e+05
# 10                        4.351101                       9.129118e+05
# 11                        3.594586                       7.541862e+05
# 12                        1.104797                       2.317993e+05
# 13                        1.108261                       2.191298e+05
# 14                        9.830754                       2.062607e+06
#
#     total_eLNG_consumption_SOFC_mass  total_eLNG_consumption_PEMFC_vol  \
# 0                       4.429255e+05                          1.140514
# 1                       5.054947e+05                          1.301627
# 2                       4.139870e+05                          1.065999
# 3                       1.778561e+05                          0.457972
# 4                       2.734251e+05                          0.704058
# 5                       2.087751e+05                          0.537587
# 6                       3.268683e+05                          0.841672
# 7                       1.296188e+05                          0.333763
# 8                       8.995375e+05                          2.316271
# 9                       3.552986e+05                          0.914879
# 10                      8.361965e+05                          2.153170
# 11                      6.908092e+05                          1.778804
# 12                      2.123203e+05                          0.546716
# 13                      2.129860e+05                          0.516834
# 14                      1.889279e+06                          4.864812
#
#     total_eLNG_consumption_SOFC_vol  total_eLNG_consumption_ICE_mass  \
# 0                          1.044673                     4.812083e+05
# 1                          1.192247                     5.491854e+05
# 2                          0.976419                     4.497685e+05
# 3                          0.419487                     1.932285e+05
# 4                          0.644893                     2.970577e+05
# 5                          0.492412                     2.268199e+05
# 6                          0.770943                     3.551201e+05
# 7                          0.305715                     1.408219e+05
# 8                          2.121626                     9.772860e+05
# 9                          0.837998                     3.860077e+05
# 10                         1.972232                     9.084704e+05
# 11                         1.629325                     7.505170e+05
# 12                         0.500773                     2.306716e+05
# 13                         0.502343                     2.542663e+05
# 14                         4.456004                     2.052572e+06
#
#     total_eLNG_consumption_ICE_vol  total_eMethanol_consumption_PEMFC_mass  \
# 0                         1.134965                            1.175751e+06
# 1                         1.295295                            1.341842e+06
# 2                         1.060813                            1.098934e+06
# 3                         0.455744                            4.721212e+05
# 4                         0.700633                            7.258103e+05
# 5                         0.534972                            5.541962e+05
# 6                         0.837577                            8.676761e+05
# 7                         0.332139                            3.440746e+05
# 8                         2.305002                            2.387834e+06
# 9                         0.910428                            9.431446e+05
# 10                        2.142695                            2.219694e+06
# 11                        1.770150                            1.833762e+06
# 12                        0.544056                            5.636070e+05
# 13                        0.599706                            5.328020e+05
# 14                        4.841144                            5.015114e+06
#
#     total_eMethanol_consumption_SOFC_mass  \
# 0                            1.076949e+06
# 1                            1.229082e+06
# 2                            1.006586e+06
# 3                            4.324472e+05
# 4                            6.648178e+05
# 5                            5.076251e+05
# 6                            7.947621e+05
# 7                            3.151608e+05
# 8                            2.187175e+06
# 9                            8.638888e+05
# 10                           2.033165e+06
# 11                           1.679664e+06
# 12                           5.162451e+05
# 13                           5.178636e+05
# 14                           4.593676e+06
#
#     total_eMethanol_consumption_PEMFC_vol  \
# 0                                1.484274
# 1                                1.693948
# 2                                1.387299
# 3                                0.596008
# 4                                0.916266
# 5                                0.699620
# 6                                1.095358
# 7                                0.434361
# 8                                3.014413
# 9                                1.190630
# 10                               2.802153
# 11                               2.314950
# 12                               0.711500
# 13                               0.672612
# 14                               6.331104
#
#     total_eMethanol_consumption_SOFC_vol  \
# 0                               1.359545
# 1                               1.551599
# 2                               1.270719
# 3                               0.545923
# 4                               0.839269
# 5                               0.640828
# 6                               1.003312
# 7                               0.397861
# 8                               2.761101
# 9                               1.090577
# 10                              2.566678
# 11                              2.120416
# 12                              0.651710
# 13                              0.653753
# 14                              5.799078
#
#     total_eMethanol_consumption_ICE_mass  total_eMethanol_consumption_ICE_vol  \
# 0                           1.170031e+06                             1.477053
# 1                           1.335314e+06                             1.685706
# 2                           1.093587e+06                             1.380550
# 3                           4.698243e+05                             0.593108
# 4                           7.222791e+05                             0.911809
# 5                           5.515000e+05                             0.696216
# 6                           8.634548e+05                             1.090029
# 7                           3.424007e+05                             0.432248
# 8                           2.376216e+06                             2.999747
# 9                           9.385561e+05                             1.184838
# 10                          2.208895e+06                             2.788520
# 11                          1.824840e+06                             2.303687
# 12                          5.608650e+05                             0.708039
# 13                          6.182343e+05                             0.780462
# 14                          4.990715e+06                             6.300302
#
#     total_eNH3_consumption_PEMFC_mass  total_eNH3_consumption_SOFC_mass  \
# 0                        1.258583e+06                      1.152820e+06
# 1                        1.436375e+06                      1.315671e+06
# 2                        1.176354e+06                      1.077500e+06
# 3                        5.053822e+05                      4.629131e+05
# 4                        7.769437e+05                      7.116543e+05
# 5                        5.932394e+05                      5.433874e+05
# 6                        9.288039e+05                      8.507532e+05
# 7                        3.683147e+05                      3.373639e+05
# 8                        2.556057e+06                      2.341262e+06
# 9                        1.009589e+06                      9.247498e+05
# 10                       2.376072e+06                      2.176402e+06
# 11                       1.962950e+06                      1.797997e+06
# 12                       6.033132e+05                      5.526146e+05
# 13                       5.703379e+05                      5.543471e+05
# 14                       5.368429e+06                      4.917301e+06
#
#     total_eNH3_consumption_PEMFC_vol  total_eNH3_consumption_SOFC_vol  \
# 0                           2.048856                         1.876683
# 1                           2.338285                         2.141790
# 2                           1.914994                         1.754070
# 3                           0.822715                         0.753580
# 4                           1.264792                         1.158507
# 5                           0.965739                         0.884584
# 6                           1.512006                         1.384947
# 7                           0.599582                         0.549197
# 8                           4.161022                         3.811357
# 9                           1.643517                         1.505407
# 10                          3.868024                         3.542980
# 11                          3.195501                         2.926971
# 12                          0.982138                         0.899605
# 13                          0.928457                         0.902426
# 14                          8.739303                         8.004908
#
#     total_eNH3_consumption_ICE_mass  total_eNH3_consumption_ICE_vol  \
# 0                      1.252460e+06                        2.038888
# 1                      1.429387e+06                        2.326909
# 2                      1.170630e+06                        1.905678
# 3                      5.029235e+05                        0.818713
# 4                      7.731638e+05                        1.258639
# 5                      5.903532e+05                        0.961040
# 6                      9.242852e+05                        1.504650
# 7                      3.665228e+05                        0.596665
# 8                      2.543621e+06                        4.140779
# 9                      1.004677e+06                        1.635521
# 10                     2.364512e+06                        3.849206
# 11                     1.953400e+06                        3.179954
# 12                     6.003780e+05                        0.977360
# 13                     6.617890e+05                        1.077331
# 14                     5.342311e+06                        8.696786
#
#     total_Li_NMC_Battery_mass  total_Li_NMC_Battery_vol  \
# 0                2.763667e+07                 21.870743
# 1                3.154072e+07                 24.960279
# 2                2.583103e+07                 20.441819
# 3                1.109746e+07                  8.782166
# 4                1.706056e+07                 13.501164
# 5                1.302668e+07                 10.308884
# 6                2.039519e+07                 16.140081
# 7                8.087660e+06                  6.400306
# 8                5.612731e+07                 44.417298
# 9                2.216912e+07                 17.543910
# 10               5.217511e+07                 41.289653
# 11               4.310356e+07                 34.110729
# 12               1.324789e+07                 10.483939
# 13               1.392834e+07                 11.022424
# 14               1.178830e+08                 93.288668
#
#     total_Battery2000kWh_consumption_num
# 0                               1.520017
# 1                               1.734739
# 2                               1.420706
# 3                               0.610361
# 4                               0.938331
# 5                               0.716467
# 6                               1.121736
# 7                               0.444821
# 8                               3.087002
# 9                               1.219302
# 10                              2.869631
# 11                              2.370696
# 12                              0.728634
# 13                              0.766058
# 14                              6.483562

# %% [markdown]
# #### upstream_total_diesel_use [kg] of main engine

# %%
upstream_total_diesel_use = (df_upstream['total_diesel_consumption_C_year_ICE_mass']/1000).sum() #kg
upstream_total_diesel_use
# Out:
# 8550.687304872585

# %%
(upstream_total_diesel_use-8226)/upstream_total_diesel_use # difference compared with the results from paper (Schweighofer & Suvacarov, 2018)
# Out:
# 0.03797207093370875

# %% [markdown]
# ### downstream energy consumption

# %%
vessel_downstream = run_simulation(path = path_downstream, **data_vessel_down)
# create an EnergyCalculation object and perform energy consumption calculation
energycalculation_downstream = opentnsim.energy.EnergyCalculation(FG, vessel_downstream)
energycalculation_downstream.calculate_energy_consumption()

# create dataframe from energy calculation computation
df_downstream = pd.DataFrame.from_dict(energycalculation_downstream.energy_use)
selected = ['edge_start','edge_stop','P_tot','P_installed','total_energy','total_diesel_consumption_C_year_ICE_mass','total_diesel_consumption_ICE_vol',
            'total_emission_CO2','total_emission_PM10','total_emission_NOX',
            'total_LH2_consumption_PEMFC_mass','total_LH2_consumption_SOFC_mass','total_LH2_consumption_PEMFC_vol','total_LH2_consumption_SOFC_vol',
           'total_eLNG_consumption_PEMFC_mass','total_eLNG_consumption_SOFC_mass','total_eLNG_consumption_PEMFC_vol','total_eLNG_consumption_SOFC_vol',
            'total_eLNG_consumption_ICE_mass','total_eLNG_consumption_ICE_vol',
            'total_eMethanol_consumption_PEMFC_mass','total_eMethanol_consumption_SOFC_mass','total_eMethanol_consumption_PEMFC_vol','total_eMethanol_consumption_SOFC_vol',
            'total_eMethanol_consumption_ICE_mass','total_eMethanol_consumption_ICE_vol','total_eNH3_consumption_PEMFC_mass','total_eNH3_consumption_SOFC_mass',
            'total_eNH3_consumption_PEMFC_vol','total_eNH3_consumption_SOFC_vol','total_eNH3_consumption_ICE_mass','total_eNH3_consumption_ICE_vol',
            'total_Li_NMC_Battery_mass','total_Li_NMC_Battery_vol','total_Battery2000kWh_consumption_num']
df_downstream = df_downstream[selected]
df_downstream
# Out:
# 220.16801469665128 SFC final
# 232.40310851037952 SFC final
# 211.46269450933383 SFC final
# 235.1221389736275 SFC final
# 207.05 SFC final
# 227.18443374070634 SFC final
# 207.05 SFC final
# 209.1 SFC final
# 209.1 SFC final
# 214.21825404944403 SFC final
# 210.38009117116187 SFC final
# 205.5041018950307 SFC final
# 225.68319965408796 SFC final
# 212.2962527114943 SFC final
# 205.0 SFC final
# C:\ANACONDA2021\envs\sim\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#             edge_start           edge_stop        P_tot  P_installed  \
# 0    POINT (6.62475 0)   POINT (5.07844 0)   304.218885        780.0
# 1    POINT (5.07844 0)   POINT (4.73879 0)   187.836285        780.0
# 2    POINT (4.73879 0)   POINT (4.54888 0)   423.051178        780.0
# 3    POINT (4.54888 0)    POINT (4.1148 0)   161.972337        780.0
# 4     POINT (4.1148 0)   POINT (3.32804 0)   513.954840        780.0
# 5    POINT (3.32804 0)   POINT (3.05674 0)   237.477338        780.0
# 6    POINT (3.05674 0)   POINT (2.20665 0)   524.540004        780.0
# 7    POINT (2.20665 0)     POINT (2.071 0)  1264.579462        780.0
# 8      POINT (2.071 0)  POINT (1.736384 0)   789.581048        780.0
# 9   POINT (1.736384 0)   POINT (1.56274 0)   370.628338        780.0
# 10   POINT (1.56274 0)   POINT (1.31495 0)   443.647046        780.0
# 11   POINT (1.31495 0)    POINT (1.1443 0)   575.409769        780.0
# 12    POINT (1.1443 0)    POINT (0.8528 0)   251.757369        780.0
# 13    POINT (0.8528 0)    POINT (0.4366 0)   407.193241        780.0
# 14    POINT (0.4366 0)         POINT (0 0)   653.433001        780.0
#
#     total_energy  total_diesel_consumption_C_year_ICE_mass  \
# 0    3276.185428                             721311.241545
# 1     592.428013                             137682.111710
# 2     559.534001                             118320.567530
# 3     489.661957                             115130.366694
# 4    2816.131771                             583080.083112
# 5     448.701690                             101938.039359
# 6    3105.483765                             642990.413619
# 7     736.885721                             154082.804249
# 8    1817.720253                             380085.304996
# 9     448.212685                              96015.338795
# 10    765.609141                             161068.920863
# 11    683.863246                             140536.702255
# 12    511.100718                             115346.845335
# 13   1180.289046                             250570.941676
# 14   1986.874957                             407309.366263
#
#     total_diesel_consumption_ICE_vol  total_emission_CO2  total_emission_PM10  \
# 0                           0.931160        2.287084e+06          1016.263202
# 1                           0.177737        4.365530e+05           201.341035
# 2                           0.152743        3.751628e+05           168.116244
# 3                           0.148625        3.650475e+05           173.234628
# 4                           0.752713        1.848791e+06           836.391136
# 5                           0.131594        3.232182e+05           145.019281
# 6                           0.830053        2.038750e+06           922.328678
# 7                           0.198910        4.885552e+05           214.433745
# 8                           0.490662        1.205149e+06           528.956594
# 9                           0.123949        3.044389e+05           135.808444
# 10                          0.207928        5.107063e+05           229.682742
# 11                          0.181423        4.456042e+05           201.560287
# 12                          0.148904        3.657339e+05           163.502216
# 13                          0.323469        7.944932e+05           356.066582
# 14                          0.525806        1.291469e+06           579.642800
#
#     total_emission_NOX  total_LH2_consumption_PEMFC_mass  \
# 0         31473.509052                     232190.349067
# 1          5943.869091                      39534.735579
# 2          5259.619610                      41535.581302
# 3          5034.910169                      32676.807271
# 4         26159.715588                     212827.593353
# 5          4382.747029                      30841.691070
# 6         28768.344774                     238632.555310
# 7          6718.924004                      61468.612024
# 8         16573.973271                     151628.316103
# 9          4234.126590                      32004.509363
# 10         7169.697520                      57222.705225
# 11         6299.748225                      54307.458333
# 12         4974.645602                      35130.713334
# 13        11094.717037                      86014.410334
# 14        18116.325861                     157783.196482
#
#     total_LH2_consumption_SOFC_mass  total_LH2_consumption_PEMFC_vol  \
# 0                     225631.419280                         3.025015
# 1                      41906.819714                         0.515065
# 2                      39466.071602                         0.541133
# 3                      34637.415707                         0.425719
# 4                     200211.253615                         2.772754
# 5                      29943.389389                         0.401811
# 6                     222469.999632                         3.108945
# 7                      56059.374166                         0.800823
# 8                     138285.024286                         1.975439
# 9                      31107.186671                         0.416960
# 10                     54157.203160                         0.745507
# 11                     49743.806373                         0.707527
# 12                     34107.488674                         0.457689
# 13                     82609.761225                         1.120610
# 14                    144524.104340                         2.055626
#
#     total_LH2_consumption_SOFC_vol  total_eLNG_consumption_PEMFC_mass  \
# 0                         2.939564                      581348.768716
# 1                         0.545969                       98985.465774
# 2                         0.514171                      103995.102056
# 3                         0.451262                       81814.863318
# 4                         2.608386                      532869.087116
# 5                         0.390108                       77220.173883
# 6                         2.898377                      597478.503145
# 7                         0.730351                      153902.615067
# 8                         1.801601                      379640.821522
# 9                         0.405270                       80131.591113
# 10                        0.705569                      143271.886015
# 11                        0.648071                      135972.809211
# 12                        0.444358                       87958.853687
# 13                        1.076254                      215359.388279
# 14                        1.882884                      395051.161116
#
#     total_eLNG_consumption_SOFC_mass  total_eLNG_consumption_PEMFC_vol  \
# 0                      564926.786619                          1.371154
# 1                      104924.593720                          0.233465
# 2                       98813.547696                          0.245280
# 3                       86723.755117                          0.192966
# 4                      501280.807924                          1.256811
# 5                       74971.042605                          0.182130
# 6                      557011.352461                          1.409197
# 7                      140359.184941                          0.362991
# 8                      346232.429228                          0.895411
# 9                       77884.910988                          0.188996
# 10                     135596.606407                          0.337917
# 11                     124546.522722                          0.320702
# 12                      85396.945327                          0.207457
# 13                     206834.966076                          0.507941
# 14                     361853.584552                          0.931757
#
#     total_eLNG_consumption_SOFC_vol  total_eLNG_consumption_ICE_mass  \
# 0                          1.332422                    696199.331652
# 1                          0.247472                    132888.812252
# 2                          0.233059                    114201.325712
# 3                          0.204544                    111122.189325
# 4                          1.182308                    562780.587327
# 5                          0.176825                     98389.142972
# 6                          1.313753                    620605.184610
# 7                          0.331048                    148718.526981
# 8                          0.816615                    366852.920166
# 9                          0.183697                     92672.636786
# 10                         0.319815                    155461.427184
# 11                         0.293752                    135644.022368
# 12                         0.201415                    111331.131424
# 13                         0.487836                    241847.502269
# 14                         0.853459                    393129.196157
#
#     total_eLNG_consumption_ICE_vol  total_eMethanol_consumption_PEMFC_mass  \
# 0                         1.642038                            1.413517e+06
# 1                         0.313428                            2.406776e+05
# 2                         0.269352                            2.528583e+05
# 3                         0.262090                            1.989283e+05
# 4                         1.327360                            1.295641e+06
# 5                         0.232058                            1.877565e+05
# 6                         1.463743                            1.452736e+06
# 7                         0.350764                            3.742056e+05
# 8                         0.865250                            9.230755e+05
# 9                         0.218575                            1.948355e+05
# 10                        0.366667                            3.483576e+05
# 11                        0.319926                            3.306103e+05
# 12                        0.262583                            2.138670e+05
# 13                        0.570415                            5.236343e+05
# 14                        0.927224                            9.605449e+05
#
#     total_eMethanol_consumption_SOFC_mass  \
# 0                            1.373588e+06
# 1                            2.551183e+05
# 2                            2.402596e+05
# 3                            2.108640e+05
# 4                            1.218836e+06
# 5                            1.822879e+05
# 6                            1.354342e+06
# 7                            3.412755e+05
# 8                            8.418448e+05
# 9                            1.893728e+05
# 10                           3.296956e+05
# 11                           3.028279e+05
# 12                           2.076379e+05
# 13                           5.029077e+05
# 14                           8.798268e+05
#
#     total_eMethanol_consumption_PEMFC_vol  \
# 0                                1.784431
# 1                                0.303833
# 2                                0.319210
# 3                                0.251128
# 4                                1.635624
# 5                                0.237025
# 6                                1.833940
# 7                                0.472399
# 8                                1.165295
# 9                                0.245961
# 10                               0.439768
# 11                               0.417364
# 12                               0.269987
# 13                               0.661039
# 14                               1.212596
#
#     total_eMethanol_consumption_SOFC_vol  \
# 0                               1.734024
# 1                               0.322063
# 2                               0.303305
# 3                               0.266196
# 4                               1.538665
# 5                               0.230121
# 6                               1.709728
# 7                               0.430828
# 8                               1.062749
# 9                               0.239065
# 10                              0.416209
# 11                              0.382291
# 12                              0.262123
# 13                              0.634873
# 14                              1.110698
#
#     total_eMethanol_consumption_ICE_mass  total_eMethanol_consumption_ICE_vol  \
# 0                           1.692770e+06                             2.136961
# 1                           3.231117e+05                             0.407898
# 2                           2.776742e+05                             0.350537
# 3                           2.701874e+05                             0.341086
# 4                           1.368370e+06                             1.727436
# 5                           2.392277e+05                             0.302002
# 6                           1.508967e+06                             1.904927
# 7                           3.616008e+05                             0.456487
# 8                           8.919824e+05                             1.126043
# 9                           2.253283e+05                             0.284456
# 10                          3.779958e+05                             0.477184
# 11                          3.298109e+05                             0.416355
# 12                          2.706954e+05                             0.341727
# 13                          5.880387e+05                             0.742343
# 14                          9.558717e+05                             1.206697
#
#     total_eNH3_consumption_PEMFC_mass  total_eNH3_consumption_SOFC_mass  \
# 0                        1.513100e+06                      1.470357e+06
# 1                        2.576334e+05                      2.730914e+05
# 2                        2.706722e+05                      2.571859e+05
# 3                        2.129428e+05                      2.257194e+05
# 4                        1.386920e+06                      1.304703e+06
# 5                        2.009840e+05                      1.951301e+05
# 6                        1.555081e+06                      1.449756e+06
# 7                        4.005685e+05                      3.653184e+05
# 8                        9.881062e+05                      9.011529e+05
# 9                        2.085617e+05                      2.027142e+05
# 10                       3.728994e+05                      3.529227e+05
# 11                       3.539018e+05                      3.241622e+05
# 12                       2.289340e+05                      2.222660e+05
# 13                       5.605244e+05                      5.383376e+05
# 14                       1.028215e+06                      9.418107e+05
#
#     total_eNH3_consumption_PEMFC_vol  total_eNH3_consumption_SOFC_vol  \
# 0                           2.463185                         2.393605
# 1                           0.419403                         0.444567
# 2                           0.440629                         0.418675
# 3                           0.346651                         0.367450
# 4                           2.257776                         2.123936
# 5                           0.327183                         0.317654
# 6                           2.531527                         2.360067
# 7                           0.652088                         0.594704
# 8                           1.608545                         1.466993
# 9                           0.339519                         0.330000
# 10                          0.607046                         0.574525
# 11                          0.576119                         0.527706
# 12                          0.372683                         0.361828
# 13                          0.912482                         0.876364
# 14                          1.673839                         1.533180
#
#     total_eNH3_consumption_ICE_mass  total_eNH3_consumption_ICE_vol  \
# 0                      1.812026e+06                        2.949809
# 1                      3.458750e+05                        0.563052
# 2                      2.972363e+05                        0.483873
# 3                      2.892221e+05                        0.470827
# 4                      1.464771e+06                        2.384512
# 5                      2.560813e+05                        0.416877
# 6                      1.615274e+06                        2.629515
# 7                      3.870756e+05                        0.630123
# 8                      9.548227e+05                        1.554362
# 9                      2.412028e+05                        0.392656
# 10                     4.046256e+05                        0.658693
# 11                     3.530461e+05                        0.574726
# 12                     2.897660e+05                        0.471712
# 13                     6.294661e+05                        1.024712
# 14                     1.023213e+06                        1.665696
#
#     total_Li_NMC_Battery_mass  total_Li_NMC_Battery_vol  \
# 0                3.722938e+07                 29.462099
# 1                6.732137e+06                  5.327590
# 2                6.358341e+06                  5.031781
# 3                5.564340e+06                  4.403435
# 4                3.200150e+07                 25.324926
# 5                5.098883e+06                  4.035087
# 6                3.528959e+07                 27.927012
# 7                8.373701e+06                  6.626670
# 8                2.065591e+07                 16.346405
# 9                5.093326e+06                  4.030690
# 10               8.700104e+06                  6.884974
# 11               7.771173e+06                  6.149849
# 12               5.807963e+06                  4.596229
# 13               1.341238e+07                 10.614110
# 14               2.257812e+07                 17.867581
#
#     total_Battery2000kWh_consumption_num
# 0                               2.047616
# 1                               0.370268
# 2                               0.349709
# 3                               0.306039
# 4                               1.760082
# 5                               0.280439
# 6                               1.940927
# 7                               0.460554
# 8                               1.136075
# 9                               0.280133
# 10                              0.478506
# 11                              0.427415
# 12                              0.319438
# 13                              0.737681
# 14                              1.241797

# %% [markdown]
# #### downstream_total_diesel_use [kg] of main engine

# %%
downstream_total_diesel_use = (df_downstream['total_diesel_consumption_C_year_ICE_mass']/1000).sum() #kg
downstream_total_diesel_use
# Out:
# 4125.469047999058

# %%
(4205-downstream_total_diesel_use)/4205 # difference compared with the results from paper (Schweighofer & Suvacarov, 2018)
# Out:
# 0.018913424970497576

# %% [markdown]
# #### roundtrip_total_diesel_use [kg] of main engine

# %%
roundtrip_total_diesel_use = upstream_total_diesel_use + downstream_total_diesel_use
roundtrip_total_diesel_use
# Out:
# 12676.156352871643

# %%
(12431-roundtrip_total_diesel_use)/12431 # difference compared with the results from paper (Schweighofer & Suvacarov, 2018)
# Out:
# -0.019721370193197918
